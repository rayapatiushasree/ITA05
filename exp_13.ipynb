# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Load the image
image_path = '/content/images.jpg'
image = cv2.imread(image_path)

# Check if image was loaded successfully
if image is None:
    print(f"Error: Could not load image from {image_path}")
else:
    # Convert BGR to RGB for displaying with matplotlib
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    print("Image loaded successfully.")

    # Display the original image
    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(image_rgb)
    plt.title('Original Image')
    plt.axis('off')
# Out:
# Image loaded successfully.

# %% [markdown]
# Now, let's define the source and destination points for the affine transformation. We will pick three non-collinear points from the original image and their corresponding desired positions in the transformed image.

# %%
# Get image dimensions
if image is not None:
    rows, cols, ch = image.shape

    # Define 3 source points (e.g., corners or distinct features)
    # These points are chosen for demonstration; you can adjust them
    pts1 = np.float32([[50, 50], [200, 50], [50, 200]])

    # Define 3 corresponding destination points
    # This transformation will shear and shift the image
    pts2 = np.float32([[10, 100], [200, 50], [100, 250]])

    # Get the affine transformation matrix
    M = cv2.getAffineTransform(pts1, pts2)

    # Apply the affine transformation
    transformed_image = cv2.warpAffine(image, M, (cols, rows))

    # Convert BGR to RGB for displaying with matplotlib
    transformed_image_rgb = cv2.cvtColor(transformed_image, cv2.COLOR_BGR2RGB)

    # Display the transformed image
    plt.subplot(1, 2, 2)
    plt.imshow(transformed_image_rgb)
    plt.title('Affine Transformed Image')
    plt.axis('off')
    plt.show()
else:
    print("Cannot perform transformation, image was not loaded.")
